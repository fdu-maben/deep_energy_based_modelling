# %%
import os
data_path = "/work/home/maben/project/blue_whale_lab/projects/pareto_ebm/project/datasets/img_align_celeba"

# %%
files = os.listdir(data_path)

# %%
print(len(files))
# Out:
# 202599

# %%
import pandas as pd
file_path = "/work/home/maben/project/blue_whale_lab/projects/pareto_ebm/project/datasets/list_attr_celeba.txt"
df = pd.read_csv(file_path,sep='\s+')

# %%
df.head()
# Out:
#             5_o_Clock_Shadow  Arched_Eyebrows  Attractive  Bags_Under_Eyes  \
# 000001.jpg                -1                1           1               -1
# 000002.jpg                -1               -1          -1                1
# 000003.jpg                -1               -1          -1               -1
# 000004.jpg                -1               -1           1               -1
# 000005.jpg                -1                1           1               -1
#
#             Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  Blond_Hair  ...  \
# 000001.jpg    -1     -1        -1        -1          -1          -1  ...
# 000002.jpg    -1     -1        -1         1          -1          -1  ...
# 000003.jpg    -1     -1         1        -1          -1          -1  ...
# 000004.jpg    -1     -1        -1        -1          -1          -1  ...
# 000005.jpg    -1     -1         1        -1          -1          -1  ...
#
# ...

# %%
df[df['Attractive']==1]
# Out:
#             5_o_Clock_Shadow  Arched_Eyebrows  Attractive  Bags_Under_Eyes  \
# 000001.jpg                -1                1           1               -1
# 000004.jpg                -1               -1           1               -1
# 000005.jpg                -1                1           1               -1
# 000006.jpg                -1                1           1               -1
# 000007.jpg                 1               -1           1                1
# ...                      ...              ...         ...              ...
# 202593.jpg                -1               -1           1               -1
# 202594.jpg                -1                1           1               -1
# 202595.jpg                -1               -1           1               -1
# 202598.jpg                -1                1           1               -1
# 202599.jpg                -1                1           1               -1
#
# ...

# %%
from IPython.display import Image, display

# 替换成你的图片路径
image_path = os.path.join(data_path,"000004.jpg")

# 展示图片
display(Image(filename=image_path))
