# %%
import torch
import numpy as np
import random
img_shape = (3,32,32)
sample_size = 64

# %%
examples = torch.cat([(torch.rand((1,)+img_shape)*2-1) for _ in range(sample_size)],dim=0)

# %%
print(examples.shape)
# Out:
# torch.Size([64, 3, 32, 32])

# %%
n_new = np.random.binomial(sample_size, 0.05)

# %%
rand_imgs = torch.rand((n_new,) + img_shape) * 2 - 1
old_imgs = torch.stack(random.choices(examples, k=sample_size-n_new), dim=0)

# %%
import os
data_path = "/work/home/maben/project/blue_whale_lab/projects/pareto_ebm/datasets/celeba/img_align_celeba"

# %%
files = os.listdir(data_path)

# %%
print(len(files))
# Out:
# 202599

# %%
import pandas as pd
file_path = "/work/home/maben/project/blue_whale_lab/projects/pareto_ebm/datasets/list_attr_celeba.txt"
df = pd.read_csv(file_path,sep='\s+')

# %%
df.head()
# Out:
#             5_o_Clock_Shadow  Arched_Eyebrows  Attractive  Bags_Under_Eyes  \
# 000001.jpg                -1                1           1               -1
# 000002.jpg                -1               -1          -1                1
# 000003.jpg                -1               -1          -1               -1
# 000004.jpg                -1               -1           1               -1
# 000005.jpg                -1                1           1               -1
#
#             Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  Blond_Hair  ...  \
# 000001.jpg    -1     -1        -1        -1          -1          -1  ...
# 000002.jpg    -1     -1        -1         1          -1          -1  ...
# 000003.jpg    -1     -1         1        -1          -1          -1  ...
# 000004.jpg    -1     -1        -1        -1          -1          -1  ...
# 000005.jpg    -1     -1         1        -1          -1          -1  ...
#
# ...

# %%
df[df['Attractive']==1].index
# Out:
# Index(['000001.jpg', '000004.jpg', '000005.jpg', '000006.jpg', '000007.jpg',
#        '000009.jpg', '000010.jpg', '000011.jpg', '000012.jpg', '000019.jpg',
#        ...
#        '202577.jpg', '202578.jpg', '202587.jpg', '202589.jpg', '202591.jpg',
#        '202593.jpg', '202594.jpg', '202595.jpg', '202598.jpg', '202599.jpg'],
#       dtype='object', length=103833)

# %%
for idx,index in enumerate(df[df['Attractive']==-1].index):
    if idx < 100:
        image_path = os.path.join(data_path,f"{index}")
        display(Image(filename=image_path))

# %%
for idx,col in enumerate(df.columns):
    print(idx)
    print(df[col].value_counts())
# Out:
# 0
# 5_o_Clock_Shadow
# -1    180083
#  1     22516
# Name: count, dtype: int64
# 1
# Arched_Eyebrows
# -1    148509
#  1     54090
# Name: count, dtype: int64
# 2
# Attractive
#  1    103833
# -1     98766
# Name: count, dtype: int64
# 3
# Bags_Under_Eyes
# -1    161153
#  1     41446
# Name: count, dtype: int64
# 4
# Bald
# -1    198052
#  1      4547
# Name: count, dtype: int64
# 5
# Bangs
# -1    171890
#  1     30709
# Name: count, dtype: int64
# 6
# Big_Lips
# -1    153814
#  1     48785
# Name: count, dtype: int64
# 7
# Big_Nose
# -1    155083
#  1     47516
# Name: count, dtype: int64
# 8
# Black_Hair
# -1    154127
#  1     48472
# Name: count, dtype: int64
# 9
# Blond_Hair
# -1    172616
#  1     29983
# Name: count, dtype: int64
# 10
# Blurry
# -1    192287
#  1     10312
# Name: count, dtype: int64
# 11
# Brown_Hair
# -1    161027
#  1     41572
# Name: count, dtype: int64
# 12
# Bushy_Eyebrows
# -1    173796
#  1     28803
# Name: count, dtype: int64
# 13
# Chubby
# ...
