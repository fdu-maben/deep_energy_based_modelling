# %%
import os
data_path = "/work/home/maben/project/blue_whale_lab/projects/pareto_ebm/datasets/celeba/img_align_celeba"

# %%
files = os.listdir(data_path)

# %%
print(len(files))
# Out:
# 202599

# %%
import pandas as pd
file_path = "/work/home/maben/project/blue_whale_lab/projects/pareto_ebm/datasets/list_attr_celeba.txt"
df = pd.read_csv(file_path,sep='\s+')

# %%
df.head()
# Out:
#             5_o_Clock_Shadow  Arched_Eyebrows  Attractive  Bags_Under_Eyes  \
# 000001.jpg                -1                1           1               -1
# 000002.jpg                -1               -1          -1                1
# 000003.jpg                -1               -1          -1               -1
# 000004.jpg                -1               -1           1               -1
# 000005.jpg                -1                1           1               -1
#
#             Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  Blond_Hair  ...  \
# 000001.jpg    -1     -1        -1        -1          -1          -1  ...
# 000002.jpg    -1     -1        -1         1          -1          -1  ...
# 000003.jpg    -1     -1         1        -1          -1          -1  ...
# 000004.jpg    -1     -1        -1        -1          -1          -1  ...
# 000005.jpg    -1     -1         1        -1          -1          -1  ...
#
#             Sideburns  Smiling  Straight_Hair  Wavy_Hair  Wearing_Earrings  \
# 000001.jpg         -1        1              1         -1                 1
# 000002.jpg         -1        1             -1         -1                -1
# 000003.jpg         -1       -1             -1          1                -1
# 000004.jpg         -1       -1              1         -1                 1
# 000005.jpg         -1       -1             -1         -1                -1
#
#             Wearing_Hat  Wearing_Lipstick  Wearing_Necklace  Wearing_Necktie  \
# 000001.jpg           -1                 1                -1               -1
# 000002.jpg           -1                -1                -1               -1
# 000003.jpg           -1                -1                -1               -1
# 000004.jpg           -1                 1                 1               -1
# 000005.jpg           -1                 1                -1               -1
#
#             Young
# 000001.jpg      1
# 000002.jpg      1
# 000003.jpg      1
# 000004.jpg      1
# 000005.jpg      1
#
# [5 rows x 40 columns]

# %%
df[df['Attractive']==1]
# Out:
#             5_o_Clock_Shadow  Arched_Eyebrows  Attractive  Bags_Under_Eyes  \
# 000001.jpg                -1                1           1               -1
# 000004.jpg                -1               -1           1               -1
# 000005.jpg                -1                1           1               -1
# 000006.jpg                -1                1           1               -1
# 000007.jpg                 1               -1           1                1
# ...                      ...              ...         ...              ...
# 202593.jpg                -1               -1           1               -1
# 202594.jpg                -1                1           1               -1
# 202595.jpg                -1               -1           1               -1
# 202598.jpg                -1                1           1               -1
# 202599.jpg                -1                1           1               -1
#
#             Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  Blond_Hair  ...  \
# 000001.jpg    -1     -1        -1        -1          -1          -1  ...
# 000004.jpg    -1     -1        -1        -1          -1          -1  ...
# 000005.jpg    -1     -1         1        -1          -1          -1  ...
# 000006.jpg    -1     -1         1        -1          -1          -1  ...
# 000007.jpg    -1     -1         1         1           1          -1  ...
# ...          ...    ...       ...       ...         ...         ...  ...
# 202593.jpg    -1      1        -1        -1          -1          -1  ...
# 202594.jpg    -1     -1         1        -1          -1          -1  ...
# 202595.jpg    -1     -1         1        -1          -1           1  ...
# 202598.jpg    -1     -1         1        -1           1          -1  ...
# 202599.jpg    -1     -1        -1        -1          -1           1  ...
#
#             Sideburns  Smiling  Straight_Hair  Wavy_Hair  Wearing_Earrings  \
# 000001.jpg         -1        1              1         -1                 1
# 000004.jpg         -1       -1              1         -1                 1
# 000005.jpg         -1       -1             -1         -1                -1
# 000006.jpg         -1       -1             -1          1                 1
# 000007.jpg         -1       -1              1         -1                -1
# ...               ...      ...            ...        ...               ...
# 202593.jpg         -1        1             -1         -1                -1
# 202594.jpg         -1       -1             -1          1                 1
# 202595.jpg         -1       -1             -1         -1                -1
# 202598.jpg         -1        1             -1          1                 1
# 202599.jpg         -1       -1             -1          1                -1
#
#             Wearing_Hat  Wearing_Lipstick  Wearing_Necklace  Wearing_Necktie  \
# 000001.jpg           -1                 1                -1               -1
# 000004.jpg           -1                 1                 1               -1
# 000005.jpg           -1                 1                -1               -1
# 000006.jpg           -1                 1                -1               -1
# 000007.jpg           -1                -1                -1               -1
# ...                 ...               ...               ...              ...
# 202593.jpg           -1                 1                -1               -1
# 202594.jpg           -1                 1                -1               -1
# 202595.jpg           -1                 1                -1               -1
# 202598.jpg           -1                 1                -1               -1
# 202599.jpg           -1                 1                -1               -1
#
#             Young
# 000001.jpg      1
# 000004.jpg      1
# 000005.jpg      1
# 000006.jpg      1
# 000007.jpg      1
# ...           ...
# 202593.jpg      1
# 202594.jpg      1
# 202595.jpg      1
# 202598.jpg      1
# 202599.jpg      1
#
# [103833 rows x 40 columns]

# %%
for idx,col in enumerate(df.columns):
    print(idx)
    print(df[col].value_counts())
# Out:
# 0
# 5_o_Clock_Shadow
# -1    180083
#  1     22516
# Name: count, dtype: int64
# 1
# Arched_Eyebrows
# -1    148509
#  1     54090
# Name: count, dtype: int64
# 2
# Attractive
#  1    103833
# -1     98766
# Name: count, dtype: int64
# 3
# Bags_Under_Eyes
# -1    161153
#  1     41446
# Name: count, dtype: int64
# 4
# Bald
# -1    198052
#  1      4547
# Name: count, dtype: int64
# 5
# Bangs
# -1    171890
#  1     30709
# Name: count, dtype: int64
# 6
# Big_Lips
# -1    153814
#  1     48785
# Name: count, dtype: int64
# 7
# Big_Nose
# -1    155083
#  1     47516
# Name: count, dtype: int64
# 8
# Black_Hair
# -1    154127
#  1     48472
# Name: count, dtype: int64
# 9
# Blond_Hair
# -1    172616
#  1     29983
# Name: count, dtype: int64
# 10
# Blurry
# -1    192287
#  1     10312
# Name: count, dtype: int64
# 11
# Brown_Hair
# -1    161027
#  1     41572
# Name: count, dtype: int64
# 12
# Bushy_Eyebrows
# -1    173796
#  1     28803
# Name: count, dtype: int64
# 13
# Chubby
# -1    190936
#  1     11663
# Name: count, dtype: int64
# 14
# Double_Chin
# -1    193140
#  1      9459
# Name: count, dtype: int64
# 15
# Eyeglasses
# -1    189406
#  1     13193
# Name: count, dtype: int64
# 16
# Goatee
# -1    189883
#  1     12716
# Name: count, dtype: int64
# 17
# Gray_Hair
# -1    194100
#  1      8499
# Name: count, dtype: int64
# 18
# Heavy_Makeup
# -1    124209
#  1     78390
# Name: count, dtype: int64
# 19
# High_Cheekbones
# -1    110410
#  1     92189
# Name: count, dtype: int64
# 20
# Male
# -1    118165
#  1     84434
# Name: count, dtype: int64
# 21
# Mouth_Slightly_Open
# -1    104657
#  1     97942
# Name: count, dtype: int64
# 22
# Mustache
# -1    194182
#  1      8417
# Name: count, dtype: int64
# 23
# Narrow_Eyes
# -1    179270
#  1     23329
# Name: count, dtype: int64
# 24
# No_Beard
#  1    169158
# -1     33441
# Name: count, dtype: int64
# 25
# Oval_Face
# -1    145032
#  1     57567
# Name: count, dtype: int64
# 26
# Pale_Skin
# -1    193898
#  1      8701
# Name: count, dtype: int64
# 27
# Pointy_Nose
# -1    146389
#  1     56210
# Name: count, dtype: int64
# 28
# Receding_Hairline
# -1    186436
#  1     16163
# Name: count, dtype: int64
# 29
# Rosy_Cheeks
# -1    189284
#  1     13315
# Name: count, dtype: int64
# 30
# Sideburns
# -1    191150
#  1     11449
# Name: count, dtype: int64
# 31
# Smiling
# -1    104930
#  1     97669
# Name: count, dtype: int64
# 32
# Straight_Hair
# -1    160377
#  1     42222
# Name: count, dtype: int64
# 33
# Wavy_Hair
# -1    137855
#  1     64744
# Name: count, dtype: int64
# 34
# Wearing_Earrings
# -1    164323
#  1     38276
# Name: count, dtype: int64
# 35
# Wearing_Hat
# -1    192781
#  1      9818
# Name: count, dtype: int64
# 36
# Wearing_Lipstick
# -1    106884
#  1     95715
# Name: count, dtype: int64
# 37
# Wearing_Necklace
# -1    177686
#  1     24913
# Name: count, dtype: int64
# 38
# Wearing_Necktie
# -1    187867
#  1     14732
# Name: count, dtype: int64
# 39
# Young
#  1    156734
# -1     45865
# Name: count, dtype: int64
